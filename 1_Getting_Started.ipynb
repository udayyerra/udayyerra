# %% [markdown]
# <a href="https://colab.research.google.com/github/udayyerra/udayyerra/blob/Learning_branch_Python/1_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2/2

# %%
3+3

# %%
9+
2 + 2

# %% [markdown]
# "This is a text cell"

# %%
print(2+2)
print(3*3)
print("this is my first use of print function")

# %%
#this is comment section to use the comment feature for my dashboard

print("this is the character section with the qoutes and below this is the print function code")

print(2+2)

2+2 # this adds 2+2

# %% [markdown]
# this is a normal text
#
# #Heading

# %%
"This is a code cell"

# %% [markdown]
# this is how i use my TEXT button on python

# %% [markdown]
# # Heading
#
#
#
# ```
# `# This is
#
# ```
# # This is formatted as code
# ```
#
#  formatted as code`
# ```

# %% [markdown]
# # Heading
#
# **bold**
#
# 1. one
# 2. two
# 3. three
#
# [here is a more info please click the link www.colab.reseach.google.com]
#
# [here is how i go to markdown link] ()

# %%
print("starting again")

# %%
# !ls
# Out:
# sample_data

# %%
print("hello, im udai and leaning python")
# Out:
# hello, im udai and leaning python

# %%
print("hello, im udai\nand\nleaning python\nthis how you do multiple line code in a single command using n as the postfix of the statement")
# Out:
# hello, im udai
# and
# leaning python
# this how you do multiple line code in a single command using n as the postfix of the statement

# %%
print("""Hello, I am Udai
I am learning Python
This is fun""")
# Out:
# Hello, I am Udai
# I am learning Python
# This is fun

# %%
print("my name is ", "udai")
print("my age is", 34)
# Out:
# my name is  udai
# my age is 34

# %%
print(f"my name is {'udai'}\nmy age is {34} and\ni live in the city {'hyderabad'}")
# Out:
# my name is udai
# my age is 34 and
# i live in the city hyderabad

# %%
name="udai"
age=34
city="hyderabad"
print(f"my name is {name.capitalize()}\ni am {age} years old\nand i live in the city {city.capitalize()}")
# Out:
# my name is Udai
# i am 34 years old
# and i live in the city Hyderabad

# %% [markdown]
# advance

# %%
name= input("Enter your name: ")
age = int(input("enter your age: "))
city = input("Enter your city: ")

print(f"hello {name.capitalize()}, you are {age} and live in {city.capitalize()}.")
# Out:
# Enter your name: udai
# enter your age: 34
# Enter your city: hyderabad
# hello Udai, you are 34 and live in Hyderabad.

# %%
name11="udai"
age11=34
city11="hyderabad"

print(f"my name is {name11}, age is {age11} and lives in the city {city11}")
# Out:
# my name is udai, age is 34 and lives in the city hyderabad

# %%
name=input("enter your name: ")
age=int(input("enter your age: "))
city=input("enter your city:")

print(f"hello my name is {name.capitalize()} and your age is {age} and live in the city {city.capitalize}")

# %%
num1 = int(input("Enter your first number: "))
num2 = int(input("Enter your second number: "))
print(num1 + num2)
# Out:
# Enter your first number: 10
# Enter your second number: 5
# 15

# %%
num1 = int(input("Enter your first number: "))
num2 = int(input("Enter your second number: "))

result= num1+num2
print(f"the sum of {num1} and {num2} is {result}")
# Out:
# Enter your first number: 10
# Enter your second number: 5
# the sum of 10 and 5 is 15

# %% [markdown]
# Conditions

# %%
num = int(input("Enter your number i will tell you if its a odd number or even: "))

if num%2==0:
  print(f"{num} is an even number")
else:
  print(f"{num} is an odd number")
# Out:
# Enter your number i will tell you if its a odd number or even: 33
# 33 is an odd number

# %%
num = int(input(f"Enter your number and i will tell you if your number is positive or negetive or something else: "))

if num>0:
  print(f"{num} is a positive number")
elif num<0:
  print(f"{num} is a Negetive number")
else:
  print(f"{num} is a Equal number")
# Out:
# Enter your number and i will tell you if your number is positive or negetive or something else: -36
# -36 is a Negetive number

# %%
print(f"{num} is a positive number")

# %%
name1 = "udai"
name2 = "yerra"

# %%
print(f"my firstname is {name1.capitalize()} and my secondname is {name2.capitalize()}")
# Out:
# my firstname is Udai and my secondname is Yerra

# %%
print("whatsup data nerds")
# Out:
# whatsup data nerds

# %%
def greet():
  return "whatsup data nerds!"

# %%
greet()
# Out:
# 'whatsup data nerds!'

# %%
job_title = "data analyst"
job_location = "Germany"
Job_salary = 90000

# %%
print(f" Job : {job_title.capitalize()}\nLocation : {job_location.capitalize()}\nSalary : ${Job_salary}")
# Out:
#  Job : Data analyst
# Location : Germany
# Salary : $90000

# %%
def display_info(title,location, salary):
    return print(f"JOB: {title}\nLocation: {location}\nSalary: ${salary}")

# %%
display_info(job_title, job_location, Job_salary)
# Out:
# JOB: data analyst
# Location: Germany
# Salary: $90000

# %%
class JobPost:
  def __init__(self, title,location,salary):
    self.title = title
    self.location = location
    self.salary = salary

# %%
class Dog:
    def __init__(self, breed):
        self.breed = breed

my_dog = Dog(input(f"enter your breed"))
print(my_dog.breed)
# Out:
# enter your breedsheru
# sheru

# %%
class jobPost1:
  def __init__(self,title,location,salary):
     self.title = title
     self.location = location
     self.salary = salary


    def display_info(self):
    return print(f"JOB: {self.title}\nLocation: {self.location}\nSalary: ${self.salary}")
# Out:
#   File "<tokenize>", line 8
#     def display_info(self):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
job = jobPost1(job_title, job_location, Job_salary)

# %%
jobPost1.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5773/1472768418.py in <cell line: 0>()
# ----> 1 jobPost1.title
#
# AttributeError: type object 'jobPost1' has no attribute 'title'
